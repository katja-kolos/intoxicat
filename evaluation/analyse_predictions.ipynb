# %%
from intoxicat_evaluation import calculate_accuracy, check_acc_for_groups

# %%
meta_data = '/mount/arbeitsdaten/studenten1/team-lab-phonetics/2023/student_directories/zeidler/intoxicat/data/meta_data_annotation_all_features_130623.json'
prediction_data = '/mount/arbeitsdaten/studenten1/team-lab-phonetics/2023/student_directories/zeidler/too_big_for_git/models/LLD/V2_bal_subset_type_full/speaker_normalised/preds/ALC_combo0_V2_ball_subset_type_full_LLD_normalised_predictions.json'

# %%
check_acc_for_groups(meta_data, prediction_data, [('content', 'isin', '[P,Q,C]')])
# Out:
# Traceback (most recent call last):
#   File "python cell", line 1, in <module>
#   File "/mount/arbeitsdaten31/studenten1/team-lab-phonetics/2023/student_directories/zeidler/intoxicat/evaluation/intoxicat_evaluation.py", line 111, in check_acc_for_groups
#     predictions_df = pd.read_json(predictions_path, orient='index')
#   File "/usr/lib64/python3.10/site-packages/pandas/util/_decorators.py", line 207, in wrapper
#     return func(*args, **kwargs)
#   File "/usr/lib64/python3.10/site-packages/pandas/util/_decorators.py", line 311, in wrapper
#     return func(*args, **kwargs)
#   File "/usr/lib64/python3.10/site-packages/pandas/io/json/_json.py", line 614, in read_json
#     return json_reader.read()
#   File "/usr/lib64/python3.10/site-packages/pandas/io/json/_json.py", line 748, in read
#     obj = self._get_object_parser(self.data)
#   File "/usr/lib64/python3.10/site-packages/pandas/io/json/_json.py", line 770, in _get_object_parser
# ...
