# %%
import json
import pandas as pd
import numpy as np

#data_path = '/mount/arbeitsdaten/studenten1/team-lab-phonetics/2023/student_directories/zeidler/too_big_for_git/preprocess/ALC_features_Functional.json'

# data_path = '/mount/arbeitsdaten/studenten1/team-lab-phonetics/2023/student_directories/zeidler/too_big_for_git/features/'

data_path_bal = '/mount/arbeitsdaten/studenten1/team-lab-phonetics/2023/student_directories/kolos/CLTeamLab/too_big_for_git/subsets/'
data_path_full = '/mount/arbeitsdaten/studenten1/team-lab-phonetics/2023/student_directories/zeidler/too_big_for_git/features/all_feature_files/'

# %%
from sklearn.model_selection import train_test_split

from sklearn.linear_model import LogisticRegression
from sklearn import naive_bayes, svm
from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import confusion_matrix
import seaborn as sn
import matplotlib.pyplot as plt

# %%
# df = pd.read_json(data_path, orient='index')
# df.head()

# %%
# from sklearn.model_selection import train_test_split

# train, test = train_test_split(df, test_size=0.2)

# %%
import os
#balanced dataset for train, full test and validate
train_df = pd.read_json(os.path.join(data_path_bal, 'V2_bal_subset_functional_content_full.json'), orient='index')
valid_df = pd.read_json(os.path.join(data_path_full, 'ALC_features_Functional_valid.json'), orient='index')
test_df = pd.read_json(os.path.join(data_path_full, 'ALC_features_Functional_test.json'), orient='index')

# %%
print (f'''Train contains {len(train_df)} examples. 
Test contains {len(test_df)} examples. 
Valid contains {len(valid_df)} examples.''')
# Out:
# Train contains 2490 examples.
# Test contains 1518 examples.
# Valid contains 1518 examples.

# %%
train_df['features'][0]
# Out:
# {'F0semitoneFrom27.5Hz_sma3nz_amean': [25.386016845703125],
#  'F0semitoneFrom27.5Hz_sma3nz_stddevNorm': [0.132520422339439],
#  'F0semitoneFrom27.5Hz_sma3nz_percentile20.0': [22.99669075012207],
#  'F0semitoneFrom27.5Hz_sma3nz_percentile50.0': [25.293516159057617],
#  'F0semitoneFrom27.5Hz_sma3nz_percentile80.0': [27.992177963256836],
#  'F0semitoneFrom27.5Hz_sma3nz_pctlrange0-2': [4.995487213134766],
#  'F0semitoneFrom27.5Hz_sma3nz_meanRisingSlope': [325.20074462890625],
#  'F0semitoneFrom27.5Hz_sma3nz_stddevRisingSlope': [499.342529296875],
#  'F0semitoneFrom27.5Hz_sma3nz_meanFallingSlope': [58.1995735168457],
#  'F0semitoneFrom27.5Hz_sma3nz_stddevFallingSlope': [45.1972541809082],
#  'loudness_sma3_amean': [0.285245925188064],
#  'loudness_sma3_stddevNorm': [0.8663835525512691],
#  'loudness_sma3_percentile20.0': [0.06510584801435401],
#  'loudness_sma3_percentile50.0': [0.22774367034435203],
#  'loudness_sma3_percentile80.0': [0.436800509691238],
#  'loudness_sma3_pctlrange0-2': [0.37169465422630305],
#  'loudness_sma3_meanRisingSlope': [5.562421798706055],
#  'loudness_sma3_stddevRisingSlope': [3.760345220565796],
#  'loudness_sma3_meanFallingSlope': [5.927839756011963],
#  'loudness_sma3_stddevFallingSlope': [4.351428508758545],
#  'spectralFlux_sma3_amean': [0.17565785348415303],
#  'spectralFlux_sma3_stddevNorm': [1.076193690299987],
#  'mfcc1_sma3_amean': [30.161745071411133],
#  'mfcc1_sma3_stddevNorm': [0.548188984394073],
#  'mfcc2_sma3_amean': [13.02122688293457],
#  'mfcc2_sma3_stddevNorm': [0.9154175519943231],
#  'mfcc3_sma3_amean': [16.923303604125977],
#  'mfcc3_sma3_stddevNorm': [0.73761773109436],
#  'mfcc4_sma3_amean': [2.772687196731567],
#  'mfcc4_sma3_stddevNorm': [4.8709306716918945],
#  'jitterLocal_sma3nz_amean': [0.046825844794511004],
#  'jitterLocal_sma3nz_stddevNorm': [1.8163866996765132],
#  'shimmerLocaldB_sma3nz_amean': [1.561715483665466],
#  'shimmerLocaldB_sma3nz_stddevNorm': [0.7510799169540401],
#  'HNRdBACF_sma3nz_amean': [3.825067520141601],
#  'HNRdBACF_sma3nz_stddevNorm': [1.010107636451721],
#  'logRelF0-H1-H2_sma3nz_amean': [6.278046131134033],
#  'logRelF0-H1-H2_sma3nz_stddevNorm': [1.4718395471572872],
#  'logRelF0-H1-A3_sma3nz_amean': [33.08097457885742],
#  'logRelF0-H1-A3_sma3nz_stddevNorm': [0.34181958436965904],
#  'F1frequency_sma3nz_amean': [508.43682861328125],
#  'F1frequency_sma3nz_stddevNorm': [0.306031018495559],
#  'F1bandwidth_sma3nz_amean': [1274.341796875],
#  'F1bandwidth_sma3nz_stddevNorm': [0.13792410492897],
#  'F1amplitudeLogRelF0_sma3nz_amean': [-80.77884674072266],
#  'F1amplitudeLogRelF0_sma3nz_stddevNorm': [-1.1036876440048211],
#  'F2frequency_sma3nz_amean': [1567.934814453125],
#  'F2frequency_sma3nz_stddevNorm': [0.17472310364246302],
#  'F2bandwidth_sma3nz_amean': [1044.0244140625],
#  'F2bandwidth_sma3nz_stddevNorm': [0.34283360838890004],
#  'F2amplitudeLogRelF0_sma3nz_amean': [-91.31063079833984],
#  'F2amplitudeLogRelF0_sma3nz_stddevNorm': [-0.8778768777847291],
#  'F3frequency_sma3nz_amean': [2597.196044921875],
#  'F3frequency_sma3nz_stddevNorm': [0.116138331592082],
#  'F3bandwidth_sma3nz_amean': [953.4761962890625],
#  'F3bandwidth_sma3nz_stddevNorm': [0.31189006567001304],
#  'F3amplitudeLogRelF0_sma3nz_amean': [-94.82725524902344],
#  'F3amplitudeLogRelF0_sma3nz_stddevNorm': [-0.8159323334693901],
#  'alphaRatioV_sma3nz_amean': [-23.746557235717773],
#  'alphaRatioV_sma3nz_stddevNorm': [-0.37340107560157704],
#  'hammarbergIndexV_sma3nz_amean': [32.1411247253418],
#  'hammarbergIndexV_sma3nz_stddevNorm': [0.279174119234085],
#  'slopeV0-500_sma3nz_amean': [0.036878995597362005],
#  'slopeV0-500_sma3nz_stddevNorm': [1.097807645797729],
#  'slopeV500-1500_sma3nz_amean': [-0.030268190428614002],
#  'slopeV500-1500_sma3nz_stddevNorm': [-0.45414617657661405],
#  'spectralFluxV_sma3nz_amean': [0.254112392663955],
#  'spectralFluxV_sma3nz_stddevNorm': [0.7603015303611751],
#  'mfcc1V_sma3nz_amean': [39.12481689453125],
#  'mfcc1V_sma3nz_stddevNorm': [0.299007982015609],
#  'mfcc2V_sma3nz_amean': [14.664987564086914],
#  'mfcc2V_sma3nz_stddevNorm': [0.8322708010673521],
#  'mfcc3V_sma3nz_amean': [20.27042579650879],
#  'mfcc3V_sma3nz_stddevNorm': [0.6475470662117],
#  'mfcc4V_sma3nz_amean': [2.580045461654663],
#  'mfcc4V_sma3nz_stddevNorm': [6.115925788879394],
#  'alphaRatioUV_sma3nz_amean': [-11.466089248657227],
#  'hammarbergIndexUV_sma3nz_amean': [19.701318740844727],
#  'slopeUV0-500_sma3nz_amean': [-0.009985108859837001],
#  'slopeUV500-1500_sma3nz_amean': [-0.009989776648581],
#  'spectralFluxUV_sma3nz_amean': [0.039650861173868006],
#  'loudnessPeaksPerSec': [4.179104328155518],
#  'VoicedSegmentsPerSec': [1.9772318601608272],
#  'MeanVoicedSegmentLengthSec': [0.31242424249649003],
#  'StddevVoicedSegmentLengthSec': [0.21114450693130402],
#  'MeanUnvoicedSegmentLength': [0.18322579562664001],
#  'StddevUnvoicedSegmentLength': [0.276211529970169],
#  'equivalentSoundLevel_dBp': [-35.0909423828125]}

# %%
train = train_df
valid = valid_df
test = test_df

# %% [markdown]
# # Majority Baseline
# (Just one dummy feature)

# %%
# this keeps one first feature -- should not be informative enough for the model to work
def features_to_vec(feature_dict):
#     out_vector = []
#     for feature in feature_dict.values():
#         out_vector.append(feature)
    return [0]

# %%
#check that it works and print the dimensions
print(f"The dataset has {len(train['features'])} data samples.")
print(f"Each data sample is a vector of {len(train['features'].apply(features_to_vec)[5])} dimensions.")
# Out:
# The dataset has 2490 data samples.
# Each data sample is a vector of 1 dimensions.

# %%
label_to_idx = {"a":1, "cna":0, "na": 0}
X_train = train['features'].apply(features_to_vec).tolist() 
y_train = [label_to_idx[x] for x in train['intoxicated']]

# X_test = test['features'].apply(features_to_vec).tolist() 
# y_test = [label_to_idx[x] for x in test['intoxicated']]

X_test = valid['features'].apply(features_to_vec).tolist() 
y_test = [label_to_idx[x] for x in valid['intoxicated']]

# %%
def evaluate_classifier(classifier, X_test, y_test):
    y_predicted = classifier.predict(X_test)
    cm = confusion_matrix(y_test, y_predicted)
    sn.heatmap(cm, annot=True, fmt='g')
    plt.xlabel('Predicted')
    plt.ylabel('Expected')

# %%
X_train[2:4]
#look at this; maybe we could collapse redundant features? like do PCA or any other dimensionality reduction
# Out:
# [[0], [0]]

# %%
y_train[:2]
# Out:
# [0, 1]

# %%
X_train = np.array(X_train)
y_train = np.array(y_train)

# %%
nb_classifier = naive_bayes.BernoulliNB()
nb_classifier.fit(X_train, y_train)
accuracy = nb_classifier.score(X_test, y_test)
accuracy
# Out:
# 0.689064558629776

# %%
evaluate_classifier(nb_classifier, X_test, y_test)

# %% [markdown]
# # Actual Baseline

# %%
# this simply flattens all the features into one long concatenated vector
def features_to_vec(feature_dict):
    out_vector = []
    for feature in feature_dict.values():
        for subfeature in feature:
            out_vector.append(subfeature)
    return out_vector

features_to_vec(train['features'][0])
# Out:
# [25.386016845703125,
#  0.132520422339439,
#  22.99669075012207,
#  25.293516159057617,
#  27.992177963256836,
#  4.995487213134766,
#  325.20074462890625,
#  499.342529296875,
#  58.1995735168457,
#  45.1972541809082,
#  0.285245925188064,
#  0.8663835525512691,
#  0.06510584801435401,
#  0.22774367034435203,
#  0.436800509691238,
#  0.37169465422630305,
#  5.562421798706055,
#  3.760345220565796,
#  5.927839756011963,
#  4.351428508758545,
#  0.17565785348415303,
#  1.076193690299987,
#  30.161745071411133,
#  0.548188984394073,
#  13.02122688293457,
#  0.9154175519943231,
#  16.923303604125977,
#  0.73761773109436,
#  2.772687196731567,
#  4.8709306716918945,
#  0.046825844794511004,
#  1.8163866996765132,
#  1.561715483665466,
#  0.7510799169540401,
#  3.825067520141601,
#  1.010107636451721,
#  6.278046131134033,
#  1.4718395471572872,
#  33.08097457885742,
#  0.34181958436965904,
#  508.43682861328125,
#  0.306031018495559,
#  1274.341796875,
#  0.13792410492897,
#  -80.77884674072266,
#  -1.1036876440048211,
#  1567.934814453125,
#  0.17472310364246302,
#  1044.0244140625,
#  0.34283360838890004,
#  -91.31063079833984,
#  -0.8778768777847291,
#  2597.196044921875,
#  0.116138331592082,
#  953.4761962890625,
#  0.31189006567001304,
#  -94.82725524902344,
#  -0.8159323334693901,
#  -23.746557235717773,
#  -0.37340107560157704,
#  32.1411247253418,
#  0.279174119234085,
#  0.036878995597362005,
#  1.097807645797729,
#  -0.030268190428614002,
#  -0.45414617657661405,
#  0.254112392663955,
#  0.7603015303611751,
#  39.12481689453125,
#  0.299007982015609,
#  14.664987564086914,
#  0.8322708010673521,
#  20.27042579650879,
#  0.6475470662117,
#  2.580045461654663,
#  6.115925788879394,
#  -11.466089248657227,
#  19.701318740844727,
#  -0.009985108859837001,
#  -0.009989776648581,
#  0.039650861173868006,
#  4.179104328155518,
#  1.9772318601608272,
#  0.31242424249649003,
#  0.21114450693130402,
#  0.18322579562664001,
#  0.276211529970169,
#  -35.0909423828125]

# %%
#check that it works and print the dimensions
print(f"The dataset has {len(train['features'])} data samples.")
print(f"Each data sample is a vector of {len(train['features'].apply(features_to_vec)[7])} dimensions.")
# Out:
# The dataset has 2490 data samples.
# Each data sample is a vector of 88 dimensions.

# %%
label_to_idx = {"a":1, "cna":0, "na": 0}
X_train = train['features'].apply(features_to_vec).tolist() 
y_train = [label_to_idx[x] for x in train['intoxicated']]

X_test = valid['features'].apply(features_to_vec).tolist() 
y_test = [label_to_idx[x] for x in valid['intoxicated']]

# %%
def evaluate_classifier(classifier, X_test, y_test):
    y_predicted = classifier.predict(X_test)
    cm = confusion_matrix(y_test, y_predicted)
    sn.heatmap(cm, annot=True, fmt='g')
    plt.xlabel('Predicted')
    plt.ylabel('Expected')

# %%
#([set([type(x) for x in y]) for y in X_train])
X_train = np.array(X_train)
y_train = np.array(y_train)

# %%
nb_classifier = naive_bayes.BernoulliNB()
nb_classifier.fit(X_train, y_train)
accuracy = nb_classifier.score(X_test, y_test)
accuracy
# Out:
# 0.5856389986824769

# %%
evaluate_classifier(nb_classifier, X_test, y_test)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import naive_bayes, svm 
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier

# %%
knn_classifier = KNeighborsClassifier()
knn_classifier.fit(X_train, y_train)
accuracy = knn_classifier.score(X_test, y_test)
accuracy
# Out:
# 0.5573122529644269

# %%
evaluate_classifier(knn_classifier, X_test, y_test)

# %%
rf_classifier = RandomForestClassifier()
rf_classifier.fit(X_train, y_train)
accuracy = rf_classifier.score(X_test, y_test)
accuracy
# Out:
# 0.7292490118577075

# %%
evaluate_classifier(rf_classifier, X_test, y_test)

# %%
svm_classifier = svm.LinearSVC()
svm_classifier.fit(X_train, y_train)
accuracy = svm_classifier.score(X_test, y_test)
accuracy
# Out:
# /mount/arbeitsdaten31/studenten1/team-lab-phonetics/2023/student_directories/kolos/NLP4/lib64/python3.10/site-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 0.31225296442687744

# %%
evaluate_classifier(svm_classifier, X_test, y_test)

# %%
svm_classifier = svm.NuSVC(kernel='poly')
svm_classifier.fit(X_train, y_train)
accuracy = svm_classifier.score(X_test, y_test)
accuracy
# Out:
# 0.6831357048748353

# %%
evaluate_classifier(svm_classifier, X_test, y_test)

# %%
logreg_classifier = LogisticRegression()
logreg_classifier.fit(X_train, y_train)
accuracy = logreg_classifier.score(X_test, y_test)
accuracy
# Out:
# /mount/arbeitsdaten31/studenten1/team-lab-phonetics/2023/student_directories/kolos/NLP4/lib64/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.6198945981554678

# %%
evaluate_classifier(logreg_classifier, X_test, y_test)

# %% [markdown]
# # Majority Baseline for the Levels (Regression Task)

# %%
from sklearn import linear_model

# %%
linmodel = linear_model.LinearRegression(fit_intercept=True)

# %%
def features_to_vec(feature_dict, i=0):
    out_vector = [list(feature_dict.values())[i][0]] #first of i-th feature only
    return out_vector

X_train = train['features'].apply(lambda x: features_to_vec(x, i=1)).tolist() 
X_test = valid['features'].apply(lambda x: features_to_vec(x, i=1)).tolist() 
y_train = train['breath alcohol concentration']
y_test = valid['breath alcohol concentration']
linmodel.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
(slope, intercept) = (linmodel.coef_[0], linmodel.intercept_)
print(slope, intercept)
# Out:
# 3.315815224288206e-05 0.00043737077318746676

# %%
from sklearn.metrics import mean_squared_error, r2_score
y_pred = linmodel.predict(X_test)
print("Mean squared error: %.2f" % mean_squared_error(y_test, y_pred))
# The coefficient of determination: 1 is perfect prediction
print("Coefficient of determination: %.2f" % r2_score(y_test, y_pred))
# Out:
# Mean squared error: 0.00
# Coefficient of determination: -0.16

# %%
import matplotlib.pyplot as plt
# Plot outputs
#based on the one dimension of features
x_test_0 = [x[0] for x in X_test]

plt.scatter(x_test_0, y_test, color="black")
plt.scatter(x_test_0, y_pred, color="blue")
#plt.plot(x_test_0, y_pred, color="blue", linewidth=3)

plt.xticks(())
plt.yticks(())

plt.show()

# %%
#Find the feature that produces the best results (the best r2_score)
r2_score_max = -1
i_max = 0
for i in range(len(train['features'][0].keys())):
    linmodel = linear_model.LinearRegression(fit_intercept=True)
    X_train = train['features'].apply(lambda x: features_to_vec(x, i=i)).tolist() 
    X_test = valid['features'].apply(lambda x: features_to_vec(x, i=i)).tolist() 
    y_train = train['breath alcohol concentration']
    y_test = valid['breath alcohol concentration']
    linmodel.fit(X_train, y_train)
    y_pred = linmodel.predict(X_test)
    r2_score_cur = r2_score(y_test, y_pred)
    if r2_score_cur > r2_score_max:
        i_max = i
        r2_score_max = r2_score_cur

# %%
print(i_max, r2_score_max)

linmodel = linear_model.LinearRegression(fit_intercept=True)
X_train = train['features'].apply(lambda x: features_to_vec(x, i=i_max)).tolist() 
X_test = valid['features'].apply(lambda x: features_to_vec(x, i=i_max)).tolist() 
y_train = train['breath alcohol concentration']
y_test = valid['breath alcohol concentration']
linmodel.fit(X_train, y_train)
y_pred = linmodel.predict(X_test)
print("Mean squared error: %.2f" % mean_squared_error(y_test, y_pred))
# The coefficient of determination: 1 is perfect prediction
print("Coefficient of determination: %.2f" % r2_score(y_test, y_pred))
plt.scatter(X_test, y_test, color="black")
plt.scatter(X_test, y_pred, color="blue")
plt.xticks(())
plt.yticks(())

plt.show()
# Out:
# 24 -0.12263859877543415
# Mean squared error: 0.00
# Coefficient of determination: -0.12

# %% [markdown]
# ## On only those who have non-0 alc level
# ### In the breath
# Feature 38 seems to be correlated with the alcohol level in blood

# %%
#Find the feature that produces the best results (the best r2_score)
r2_score_max = -1
i_max = 0
for i in range(len(train['features'][0].keys())):
    linmodel = linear_model.LinearRegression(fit_intercept=True)
    X_train = train['features'].apply(lambda x: features_to_vec(x, i=i)).tolist() 
    X_test = valid['features'].apply(lambda x: features_to_vec(x, i=i)).tolist() 
    y_train = train['breath alcohol concentration']
    y_test = valid['breath alcohol concentration']
    linmodel.fit(X_train, y_train)
    y_pred = linmodel.predict(X_test)
    r2_score_cur = r2_score(y_test, y_pred)
    if r2_score_cur > r2_score_max:
        i_max = i
        r2_score_max = r2_score_cur
        
print(i_max, r2_score_max)

linmodel = linear_model.LinearRegression(fit_intercept=True)
X_train = train['features'].apply(lambda x: features_to_vec(x, i=i_max)).tolist() 
X_test = valid['features'].apply(lambda x: features_to_vec(x, i=i_max)).tolist() 
y_train = train['breath alcohol concentration']
y_test = valid['breath alcohol concentration']
linmodel.fit(X_train, y_train)
y_pred = linmodel.predict(X_test)
print("Mean squared error: %.2f" % mean_squared_error(y_test, y_pred))
# The coefficient of determination: 1 is perfect prediction
print("Coefficient of determination: %.2f" % r2_score(y_test, y_pred))
plt.scatter(X_test, y_test, color="black")
plt.scatter(X_test, y_pred, color="blue")
plt.xticks(())
plt.yticks(())

plt.show()
# Out:
# 24 -0.12263859877543415
# Mean squared error: 0.00
# Coefficient of determination: -0.12

# %%
# !pwd
# Out:
# /mount/arbeitsdaten31/studenten1/team-lab-phonetics/2023/student_directories/kolos/CLTeamLab/intoxicat/baselines
