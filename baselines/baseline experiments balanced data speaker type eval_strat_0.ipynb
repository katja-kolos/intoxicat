# %%
import json
import pandas as pd
import numpy as np

#data_path = '/mount/arbeitsdaten/studenten1/team-lab-phonetics/2023/student_directories/zeidler/too_big_for_git/preprocess/ALC_features_Functional.json'

# data_path = '/mount/arbeitsdaten/studenten1/team-lab-phonetics/2023/student_directories/zeidler/too_big_for_git/features/'

data_path_bal = '/mount/arbeitsdaten/studenten1/team-lab-phonetics/2023/student_directories/kolos/CLTeamLab/too_big_for_git/subsets/'
data_path_full = '/mount/arbeitsdaten/studenten1/team-lab-phonetics/2023/student_directories/zeidler/too_big_for_git/features/all_feature_files/'

# %%
from sklearn.model_selection import train_test_split

from sklearn.linear_model import LogisticRegression
from sklearn import naive_bayes, svm
from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import confusion_matrix
import seaborn as sn
import matplotlib.pyplot as plt

# %%
# df = pd.read_json(data_path, orient='index')
# df.head()

# %%
# from sklearn.model_selection import train_test_split

# train, test = train_test_split(df, test_size=0.2)

# %%
import os
#balanced dataset for train, full test and validate
train_df = pd.read_json(os.path.join(data_path_bal, 'V2_bal_subset_functional_type_full.json'), orient='index')
valid_df = pd.read_json(os.path.join(data_path_full, 'ALC_features_Functional_valid.json'), orient='index')
test_df = pd.read_json(os.path.join(data_path_full, 'ALC_features_Functional_test.json'), orient='index')

# %%
print (f'''Train contains {len(train_df)} examples. 
Test contains {len(test_df)} examples. 
Valid contains {len(valid_df)} examples.''')
# Out:
# Train contains 1604 examples.
# Test contains 1518 examples.
# Valid contains 1518 examples.

# %%
train_df['features'][0]
# Out:
# {'F0semitoneFrom27.5Hz_sma3nz_amean': [22.63565444946289],
#  'F0semitoneFrom27.5Hz_sma3nz_stddevNorm': [0.17959140241146002],
#  'F0semitoneFrom27.5Hz_sma3nz_percentile20.0': [20.11815643310547],
#  'F0semitoneFrom27.5Hz_sma3nz_percentile50.0': [22.4698486328125],
#  'F0semitoneFrom27.5Hz_sma3nz_percentile80.0': [25.830039978027344],
#  'F0semitoneFrom27.5Hz_sma3nz_pctlrange0-2': [5.711883544921875],
#  'F0semitoneFrom27.5Hz_sma3nz_meanRisingSlope': [203.0100555419922],
#  'F0semitoneFrom27.5Hz_sma3nz_stddevRisingSlope': [166.25990295410156],
#  'F0semitoneFrom27.5Hz_sma3nz_meanFallingSlope': [119.34738159179688],
#  'F0semitoneFrom27.5Hz_sma3nz_stddevFallingSlope': [199.61070251464844],
#  'loudness_sma3_amean': [0.2637839615345],
#  'loudness_sma3_stddevNorm': [0.8955326080322261],
#  'loudness_sma3_percentile20.0': [0.075384981930255],
#  'loudness_sma3_percentile50.0': [0.20627452433109203],
#  'loudness_sma3_percentile80.0': [0.41235613822937],
#  'loudness_sma3_pctlrange0-2': [0.33697116374969405],
#  'loudness_sma3_meanRisingSlope': [4.696968078613281],
#  'loudness_sma3_stddevRisingSlope': [3.38243818283081],
#  'loudness_sma3_meanFallingSlope': [5.264526844024658],
#  'loudness_sma3_stddevFallingSlope': [3.542561531066894],
#  'spectralFlux_sma3_amean': [0.12610591948032301],
#  'spectralFlux_sma3_stddevNorm': [1.248007655143737],
#  'mfcc1_sma3_amean': [18.25408363342285],
#  'mfcc1_sma3_stddevNorm': [0.9921528100967401],
#  'mfcc2_sma3_amean': [11.977197647094727],
#  'mfcc2_sma3_stddevNorm': [0.8853660821914671],
#  'mfcc3_sma3_amean': [13.696961402893066],
#  'mfcc3_sma3_stddevNorm': [0.946430027484893],
#  'mfcc4_sma3_amean': [7.771235466003418],
#  'mfcc4_sma3_stddevNorm': [1.592771887779235],
#  'jitterLocal_sma3nz_amean': [0.067237794399261],
#  'jitterLocal_sma3nz_stddevNorm': [1.811507701873779],
#  'shimmerLocaldB_sma3nz_amean': [1.4852432012557981],
#  'shimmerLocaldB_sma3nz_stddevNorm': [0.8428158164024351],
#  'HNRdBACF_sma3nz_amean': [1.904372572898864],
#  'HNRdBACF_sma3nz_stddevNorm': [2.245699644088745],
#  'logRelF0-H1-H2_sma3nz_amean': [4.556733131408691],
#  'logRelF0-H1-H2_sma3nz_stddevNorm': [2.709311485290527],
#  'logRelF0-H1-A3_sma3nz_amean': [27.30341339111328],
#  'logRelF0-H1-A3_sma3nz_stddevNorm': [0.475683778524398],
#  'F1frequency_sma3nz_amean': [479.1695556640625],
#  'F1frequency_sma3nz_stddevNorm': [0.405815720558166],
#  'F1bandwidth_sma3nz_amean': [1231.9039306640625],
#  'F1bandwidth_sma3nz_stddevNorm': [0.20062395930290203],
#  'F1amplitudeLogRelF0_sma3nz_amean': [-107.58036041259766],
#  'F1amplitudeLogRelF0_sma3nz_stddevNorm': [-0.8591289520263671],
#  'F2frequency_sma3nz_amean': [1480.983154296875],
#  'F2frequency_sma3nz_stddevNorm': [0.17888949811458502],
#  'F2bandwidth_sma3nz_amean': [947.1148681640625],
#  'F2bandwidth_sma3nz_stddevNorm': [0.414972066879272],
#  'F2amplitudeLogRelF0_sma3nz_amean': [-113.90593719482422],
#  'F2amplitudeLogRelF0_sma3nz_stddevNorm': [-0.74560260772705],
#  'F3frequency_sma3nz_amean': [2499.7353515625],
#  'F3frequency_sma3nz_stddevNorm': [0.10918718576431201],
#  'F3bandwidth_sma3nz_amean': [801.128662109375],
#  'F3bandwidth_sma3nz_stddevNorm': [0.38423207402229304],
#  'F3amplitudeLogRelF0_sma3nz_amean': [-115.89543151855469],
#  'F3amplitudeLogRelF0_sma3nz_stddevNorm': [-0.7147691249847411],
#  'alphaRatioV_sma3nz_amean': [-18.835037231445312],
#  'alphaRatioV_sma3nz_stddevNorm': [-0.44959214329719505],
#  'hammarbergIndexV_sma3nz_amean': [26.598411560058594],
#  'hammarbergIndexV_sma3nz_stddevNorm': [0.36702591180801303],
#  'slopeV0-500_sma3nz_amean': [0.030051499605178004],
#  'slopeV0-500_sma3nz_stddevNorm': [1.131253719329834],
#  'slopeV500-1500_sma3nz_amean': [-0.022216496989130002],
#  'slopeV500-1500_sma3nz_stddevNorm': [-0.526430964469909],
#  'spectralFluxV_sma3nz_amean': [0.21039317548274902],
#  'spectralFluxV_sma3nz_stddevNorm': [0.8500504493713371],
#  'mfcc1V_sma3nz_amean': [31.04805564880371],
#  'mfcc1V_sma3nz_stddevNorm': [0.40640294551849304],
#  'mfcc2V_sma3nz_amean': [14.396707534790039],
#  'mfcc2V_sma3nz_stddevNorm': [0.73243510723114],
#  'mfcc3V_sma3nz_amean': [18.938091278076172],
#  'mfcc3V_sma3nz_stddevNorm': [0.6857501268386841],
#  'mfcc4V_sma3nz_amean': [8.934454917907715],
#  'mfcc4V_sma3nz_stddevNorm': [1.550363540649414],
#  'alphaRatioUV_sma3nz_amean': [-6.354485511779785],
#  'hammarbergIndexUV_sma3nz_amean': [14.102752685546875],
#  'slopeUV0-500_sma3nz_amean': [0.0016173853073260002],
#  'slopeUV500-1500_sma3nz_amean': [-0.004268504213541],
#  'spectralFluxUV_sma3nz_amean': [0.043676555156707],
#  'loudnessPeaksPerSec': [2.9458179473876953],
#  'VoicedSegmentsPerSec': [2.267932653427124],
#  'MeanVoicedSegmentLengthSec': [0.209534883499145],
#  'StddevVoicedSegmentLengthSec': [0.169155955314636],
#  'MeanUnvoicedSegmentLength': [0.22073170542716902],
#  'StddevUnvoicedSegmentLength': [0.39063671231269803],
#  'equivalentSoundLevel_dBp': [-37.584739685058594]}

# %%
train = train_df
valid = valid_df
test = test_df

# %% [markdown]
# # Majority Baseline
# (Just one dummy feature)

# %%
# this keeps one first feature -- should not be informative enough for the model to work
def features_to_vec(feature_dict):
#     out_vector = []
#     for feature in feature_dict.values():
#         out_vector.append(feature)
    return [0]

# %%
#check that it works and print the dimensions
print(f"The dataset has {len(train['features'])} data samples.")
print(f"Each data sample is a vector of {len(train['features'].apply(features_to_vec)[5])} dimensions.")
# Out:
# The dataset has 1604 data samples.
# Each data sample is a vector of 1 dimensions.

# %%
label_to_idx = {"a":1, "cna":0, "na": 0}
X_train = train['features'].apply(features_to_vec).tolist() 
y_train = [label_to_idx[x] for x in train['intoxicated']]

# X_test = test['features'].apply(features_to_vec).tolist() 
# y_test = [label_to_idx[x] for x in test['intoxicated']]

X_test = valid['features'].apply(features_to_vec).tolist() 
y_test = [label_to_idx[x] for x in valid['intoxicated']]

# %%
def evaluate_classifier(classifier, X_test, y_test):
    y_predicted = classifier.predict(X_test)
    cm = confusion_matrix(y_test, y_predicted)
    sn.heatmap(cm, annot=True, fmt='g')
    plt.xlabel('Predicted')
    plt.ylabel('Expected')

# %%
X_train[2:4]
#look at this; maybe we could collapse redundant features? like do PCA or any other dimensionality reduction
# Out:
# [[0], [0]]

# %%
y_train[:2]
# Out:
# [1, 1]

# %%
X_train = np.array(X_train)
y_train = np.array(y_train)

# %%
nb_classifier = naive_bayes.BernoulliNB()
nb_classifier.fit(X_train, y_train)
accuracy = nb_classifier.score(X_test, y_test)
accuracy
# Out:
# 0.689064558629776

# %%
evaluate_classifier(nb_classifier, X_test, y_test)

# %% [markdown]
# # Actual Baseline

# %%
# this simply flattens all the features into one long concatenated vector
def features_to_vec(feature_dict):
    out_vector = []
    for feature in feature_dict.values():
        for subfeature in feature:
            out_vector.append(subfeature)
    return out_vector

features_to_vec(train['features'][0])
# Out:
# [22.63565444946289,
#  0.17959140241146002,
#  20.11815643310547,
#  22.4698486328125,
#  25.830039978027344,
#  5.711883544921875,
#  203.0100555419922,
#  166.25990295410156,
#  119.34738159179688,
#  199.61070251464844,
#  0.2637839615345,
#  0.8955326080322261,
#  0.075384981930255,
#  0.20627452433109203,
#  0.41235613822937,
#  0.33697116374969405,
#  4.696968078613281,
#  3.38243818283081,
#  5.264526844024658,
#  3.542561531066894,
#  0.12610591948032301,
#  1.248007655143737,
#  18.25408363342285,
#  0.9921528100967401,
#  11.977197647094727,
#  0.8853660821914671,
#  13.696961402893066,
#  0.946430027484893,
#  7.771235466003418,
#  1.592771887779235,
#  0.067237794399261,
#  1.811507701873779,
#  1.4852432012557981,
#  0.8428158164024351,
#  1.904372572898864,
#  2.245699644088745,
#  4.556733131408691,
#  2.709311485290527,
#  27.30341339111328,
#  0.475683778524398,
#  479.1695556640625,
#  0.405815720558166,
#  1231.9039306640625,
#  0.20062395930290203,
#  -107.58036041259766,
#  -0.8591289520263671,
#  1480.983154296875,
#  0.17888949811458502,
#  947.1148681640625,
#  0.414972066879272,
#  -113.90593719482422,
#  -0.74560260772705,
#  2499.7353515625,
#  0.10918718576431201,
#  801.128662109375,
#  0.38423207402229304,
#  -115.89543151855469,
#  -0.7147691249847411,
#  -18.835037231445312,
#  -0.44959214329719505,
#  26.598411560058594,
#  0.36702591180801303,
#  0.030051499605178004,
#  1.131253719329834,
#  -0.022216496989130002,
#  -0.526430964469909,
#  0.21039317548274902,
#  0.8500504493713371,
#  31.04805564880371,
#  0.40640294551849304,
#  14.396707534790039,
#  0.73243510723114,
#  18.938091278076172,
#  0.6857501268386841,
#  8.934454917907715,
#  1.550363540649414,
#  -6.354485511779785,
#  14.102752685546875,
#  0.0016173853073260002,
#  -0.004268504213541,
#  0.043676555156707,
#  2.9458179473876953,
#  2.267932653427124,
#  0.209534883499145,
#  0.169155955314636,
#  0.22073170542716902,
#  0.39063671231269803,
#  -37.584739685058594]

# %%
#check that it works and print the dimensions
print(f"The dataset has {len(train['features'])} data samples.")
print(f"Each data sample is a vector of {len(train['features'].apply(features_to_vec)[7])} dimensions.")
# Out:
# The dataset has 1604 data samples.
# Each data sample is a vector of 88 dimensions.

# %%
label_to_idx = {"a":1, "cna":0, "na": 0}
X_train = train['features'].apply(features_to_vec).tolist() 
y_train = [label_to_idx[x] for x in train['intoxicated']]

X_test = valid['features'].apply(features_to_vec).tolist() 
y_test = [label_to_idx[x] for x in valid['intoxicated']]

# %%
def evaluate_classifier(classifier, X_test, y_test):
    y_predicted = classifier.predict(X_test)
    cm = confusion_matrix(y_test, y_predicted)
    sn.heatmap(cm, annot=True, fmt='g')
    plt.xlabel('Predicted')
    plt.ylabel('Expected')

# %%
#([set([type(x) for x in y]) for y in X_train])
X_train = np.array(X_train)
y_train = np.array(y_train)

# %%
nb_classifier = naive_bayes.BernoulliNB()
nb_classifier.fit(X_train, y_train)
accuracy = nb_classifier.score(X_test, y_test)
accuracy
# Out:
# 0.6073781291172595

# %%
evaluate_classifier(nb_classifier, X_test, y_test)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import naive_bayes, svm 
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier

# %%
knn_classifier = KNeighborsClassifier()
knn_classifier.fit(X_train, y_train)
accuracy = knn_classifier.score(X_test, y_test)
accuracy
# Out:
# 0.5434782608695652

# %%
evaluate_classifier(knn_classifier, X_test, y_test)

# %%
rf_classifier = RandomForestClassifier()
rf_classifier.fit(X_train, y_train)
accuracy = rf_classifier.score(X_test, y_test)
accuracy
# Out:
# 0.6824769433465085

# %%
evaluate_classifier(rf_classifier, X_test, y_test)

# %%
svm_classifier = svm.LinearSVC()
svm_classifier.fit(X_train, y_train)
accuracy = svm_classifier.score(X_test, y_test)
accuracy
# Out:
# /mount/arbeitsdaten31/studenten1/team-lab-phonetics/2023/student_directories/kolos/NLP4/lib64/python3.10/site-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 0.691699604743083

# %%
evaluate_classifier(svm_classifier, X_test, y_test)

# %%
svm_classifier = svm.NuSVC(kernel='poly')
svm_classifier.fit(X_train, y_train)
accuracy = svm_classifier.score(X_test, y_test)
accuracy
# Out:
# 0.5573122529644269

# %%
evaluate_classifier(svm_classifier, X_test, y_test)

# %%
logreg_classifier = LogisticRegression()
logreg_classifier.fit(X_train, y_train)
accuracy = logreg_classifier.score(X_test, y_test)
accuracy
# Out:
# /mount/arbeitsdaten31/studenten1/team-lab-phonetics/2023/student_directories/kolos/NLP4/lib64/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.6251646903820817

# %%
evaluate_classifier(logreg_classifier, X_test, y_test)

# %% [markdown]
# # Majority Baseline for the Levels (Regression Task)

# %%
from sklearn import linear_model

# %%
linmodel = linear_model.LinearRegression(fit_intercept=True)

# %%
def features_to_vec(feature_dict, i=0):
    out_vector = [list(feature_dict.values())[i][0]] #first of i-th feature only
    return out_vector

X_train = train['features'].apply(lambda x: features_to_vec(x, i=1)).tolist() 
X_test = valid['features'].apply(lambda x: features_to_vec(x, i=1)).tolist() 
y_train = train['breath alcohol concentration']
y_test = valid['breath alcohol concentration']
linmodel.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
(slope, intercept) = (linmodel.coef_[0], linmodel.intercept_)
print(slope, intercept)
# Out:
# 8.225056761520524e-05 0.000428526353307029

# %%
from sklearn.metrics import mean_squared_error, r2_score
y_pred = linmodel.predict(X_test)
print("Mean squared error: %.2f" % mean_squared_error(y_test, y_pred))
# The coefficient of determination: 1 is perfect prediction
print("Coefficient of determination: %.2f" % r2_score(y_test, y_pred))
# Out:
# Mean squared error: 0.00
# Coefficient of determination: -0.16

# %%
import matplotlib.pyplot as plt
# Plot outputs
#based on the one dimension of features
x_test_0 = [x[0] for x in X_test]

plt.scatter(x_test_0, y_test, color="black")
plt.scatter(x_test_0, y_pred, color="blue")
#plt.plot(x_test_0, y_pred, color="blue", linewidth=3)

plt.xticks(())
plt.yticks(())

plt.show()

# %%
#Find the feature that produces the best results (the best r2_score)
r2_score_max = -1
i_max = 0
for i in range(len(train['features'][0].keys())):
    linmodel = linear_model.LinearRegression(fit_intercept=True)
    X_train = train['features'].apply(lambda x: features_to_vec(x, i=i)).tolist() 
    X_test = valid['features'].apply(lambda x: features_to_vec(x, i=i)).tolist() 
    y_train = train['breath alcohol concentration']
    y_test = valid['breath alcohol concentration']
    linmodel.fit(X_train, y_train)
    y_pred = linmodel.predict(X_test)
    r2_score_cur = r2_score(y_test, y_pred)
    if r2_score_cur > r2_score_max:
        i_max = i
        r2_score_max = r2_score_cur

# %%
print(i_max, r2_score_max)

linmodel = linear_model.LinearRegression(fit_intercept=True)
X_train = train['features'].apply(lambda x: features_to_vec(x, i=i_max)).tolist() 
X_test = valid['features'].apply(lambda x: features_to_vec(x, i=i_max)).tolist() 
y_train = train['breath alcohol concentration']
y_test = valid['breath alcohol concentration']
linmodel.fit(X_train, y_train)
y_pred = linmodel.predict(X_test)
print("Mean squared error: %.2f" % mean_squared_error(y_test, y_pred))
# The coefficient of determination: 1 is perfect prediction
print("Coefficient of determination: %.2f" % r2_score(y_test, y_pred))
plt.scatter(X_test, y_test, color="black")
plt.scatter(X_test, y_pred, color="blue")
plt.xticks(())
plt.yticks(())

plt.show()
# Out:
# 67 -0.12391099380765302
# Mean squared error: 0.00
# Coefficient of determination: -0.12

# %% [markdown]
# ## On only those who have non-0 alc level
# ### In the breath
# Feature 38 seems to be correlated with the alcohol level in blood

# %%
#Find the feature that produces the best results (the best r2_score)
r2_score_max = -1
i_max = 0
for i in range(len(train['features'][0].keys())):
    linmodel = linear_model.LinearRegression(fit_intercept=True)
    X_train = train['features'].apply(lambda x: features_to_vec(x, i=i)).tolist() 
    X_test = valid['features'].apply(lambda x: features_to_vec(x, i=i)).tolist() 
    y_train = train['breath alcohol concentration']
    y_test = valid['breath alcohol concentration']
    linmodel.fit(X_train, y_train)
    y_pred = linmodel.predict(X_test)
    r2_score_cur = r2_score(y_test, y_pred)
    if r2_score_cur > r2_score_max:
        i_max = i
        r2_score_max = r2_score_cur
        
print(i_max, r2_score_max)

linmodel = linear_model.LinearRegression(fit_intercept=True)
X_train = train['features'].apply(lambda x: features_to_vec(x, i=i_max)).tolist() 
X_test = valid['features'].apply(lambda x: features_to_vec(x, i=i_max)).tolist() 
y_train = train['breath alcohol concentration']
y_test = valid['breath alcohol concentration']
linmodel.fit(X_train, y_train)
y_pred = linmodel.predict(X_test)
print("Mean squared error: %.2f" % mean_squared_error(y_test, y_pred))
# The coefficient of determination: 1 is perfect prediction
print("Coefficient of determination: %.2f" % r2_score(y_test, y_pred))
plt.scatter(X_test, y_test, color="black")
plt.scatter(X_test, y_pred, color="blue")
plt.xticks(())
plt.yticks(())

plt.show()
# Out:
# 67 -0.12391099380765302
# Mean squared error: 0.00
# Coefficient of determination: -0.12

# %%
# !pwd
# Out:
# /mount/arbeitsdaten31/studenten1/team-lab-phonetics/2023/student_directories/kolos/CLTeamLab/intoxicat/baselines
