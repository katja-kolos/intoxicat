# %%
import json
import pandas as pd
import numpy as np

#data_path = '/mount/arbeitsdaten/studenten1/team-lab-phonetics/2023/student_directories/zeidler/too_big_for_git/preprocess/ALC_features_Functional.json'

# data_path = '/mount/arbeitsdaten/studenten1/team-lab-phonetics/2023/student_directories/zeidler/too_big_for_git/features/'

data_path = '/mount/arbeitsdaten/studenten1/team-lab-phonetics/2023/student_directories/zeidler/too_big_for_git/features/currently_used/filtered_class_balanced/speaker_normalised/'

# %%
from sklearn.model_selection import train_test_split

from sklearn.linear_model import LogisticRegression
from sklearn import naive_bayes, svm
from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import confusion_matrix
import seaborn as sn
import matplotlib.pyplot as plt

# %%
# df = pd.read_json(data_path, orient='index')
# df.head()

# %%
# from sklearn.model_selection import train_test_split

# train, test = train_test_split(df, test_size=0.2)

# %%
import os
train_df = pd.read_json(os.path.join(data_path, 'filtered_features_balanced_Functional_normalised_train.json'), orient='index')
valid_df = pd.read_json(os.path.join(data_path, 'filtered_features_balanced_Functional_normalised_valid.json'), orient='index')
test_df = pd.read_json(os.path.join(data_path, 'filtered_features_balanced_Functional_normalised_test.json'), orient='index')

# %%
print (f'''Train contains {len(train_df)} examples. 
Test contains {len(test_df)} examples. 
Valid contains {len(valid_df)} examples.''')
# Out:
# Train contains 7776 examples.
# Test contains 972 examples.
# Valid contains 972 examples.

# %%
train_df['features'][0]
# Out:
# {'F0semitoneFrom27.5Hz_sma3nz_amean': [1.9716836226420051],
#  'F0semitoneFrom27.5Hz_sma3nz_stddevNorm': [-0.144710119756208],
#  'F0semitoneFrom27.5Hz_sma3nz_percentile20.0': [1.09525820981226],
#  'F0semitoneFrom27.5Hz_sma3nz_percentile50.0': [1.4110744244268552],
#  'F0semitoneFrom27.5Hz_sma3nz_percentile80.0': [1.257443689834028],
#  'F0semitoneFrom27.5Hz_sma3nz_pctlrange0-2': [-0.062309013348470006],
#  'F0semitoneFrom27.5Hz_sma3nz_meanRisingSlope': [1.9183377363840561],
#  'F0semitoneFrom27.5Hz_sma3nz_stddevRisingSlope': [2.414238571757887],
#  'F0semitoneFrom27.5Hz_sma3nz_meanFallingSlope': [0.234921312543125],
#  'F0semitoneFrom27.5Hz_sma3nz_stddevFallingSlope': [0.44480466452833106],
#  'loudness_sma3_amean': [-0.131543291107991],
#  'loudness_sma3_stddevNorm': [-0.075182715121929],
#  'loudness_sma3_percentile20.0': [-0.724745500054306],
#  'loudness_sma3_percentile50.0': [0.035368339852342],
#  'loudness_sma3_percentile80.0': [0.13274961484936001],
#  'loudness_sma3_pctlrange0-2': [0.36253534443859503],
#  'loudness_sma3_meanRisingSlope': [1.145226168257222],
#  'loudness_sma3_stddevRisingSlope': [0.826900465550189],
#  'loudness_sma3_meanFallingSlope': [0.13682685733003702],
#  'loudness_sma3_stddevFallingSlope': [0.16099921669721],
#  'spectralFlux_sma3_amean': [-0.225905533859719],
#  'spectralFlux_sma3_stddevNorm': [-0.608610334621792],
#  'mfcc1_sma3_amean': [-2.143077865371419],
#  'mfcc1_sma3_stddevNorm': [3.064789464753881],
#  'mfcc2_sma3_amean': [0.28362095379705404],
#  'mfcc2_sma3_stddevNorm': [0.101592686331052],
#  'mfcc3_sma3_amean': [-0.8785332023988071],
#  'mfcc3_sma3_stddevNorm': [0.46776321517475905],
#  'mfcc4_sma3_amean': [-0.072546235028042],
#  'mfcc4_sma3_stddevNorm': [-0.6589946129575951],
#  'jitterLocal_sma3nz_amean': [-0.37185159196093803],
#  'jitterLocal_sma3nz_stddevNorm': [-0.610042380180256],
#  'shimmerLocaldB_sma3nz_amean': [1.476049895105589],
#  'shimmerLocaldB_sma3nz_stddevNorm': [-0.295763687665587],
#  'HNRdBACF_sma3nz_amean': [-0.372236442130687],
#  'HNRdBACF_sma3nz_stddevNorm': [0.47112731636498506],
#  'logRelF0-H1-H2_sma3nz_amean': [0.6522588570566861],
#  'logRelF0-H1-H2_sma3nz_stddevNorm': [-0.6971172461035231],
#  'logRelF0-H1-A3_sma3nz_amean': [-0.081598805976287],
#  'logRelF0-H1-A3_sma3nz_stddevNorm': [-0.20569376925886002],
#  'F1frequency_sma3nz_amean': [0.9535757340689801],
#  'F1frequency_sma3nz_stddevNorm': [1.077640186944848],
#  'F1bandwidth_sma3nz_amean': [-0.968507543591387],
#  'F1bandwidth_sma3nz_stddevNorm': [0.913639244653036],
#  'F1amplitudeLogRelF0_sma3nz_amean': [-0.090339542472001],
#  'F1amplitudeLogRelF0_sma3nz_stddevNorm': [0.137648015602948],
#  'F2frequency_sma3nz_amean': [0.394878664908461],
#  'F2frequency_sma3nz_stddevNorm': [0.030714203444137004],
#  'F2bandwidth_sma3nz_amean': [-0.255906444303623],
#  'F2bandwidth_sma3nz_stddevNorm': [0.001834435016838],
#  'F2amplitudeLogRelF0_sma3nz_amean': [0.013705637332721001],
#  'F2amplitudeLogRelF0_sma3nz_stddevNorm': [-0.018149402984678],
#  'F3frequency_sma3nz_amean': [0.134751975986],
#  'F3frequency_sma3nz_stddevNorm': [0.065574174320423],
#  'F3bandwidth_sma3nz_amean': [0.45875858209152504],
#  'F3bandwidth_sma3nz_stddevNorm': [1.3883923847296091],
#  'F3amplitudeLogRelF0_sma3nz_amean': [0.035420642104874],
#  'F3amplitudeLogRelF0_sma3nz_stddevNorm': [-0.060042464987674],
#  'alphaRatioV_sma3nz_amean': [1.094852157832998],
#  'alphaRatioV_sma3nz_stddevNorm': [-2.211069801185894],
#  'hammarbergIndexV_sma3nz_amean': [-1.161851841529184],
#  'hammarbergIndexV_sma3nz_stddevNorm': [2.813482213784022],
#  'slopeV0-500_sma3nz_amean': [0.45869376014120805],
#  'slopeV0-500_sma3nz_stddevNorm': [-0.089014351934321],
#  'slopeV500-1500_sma3nz_amean': [-0.5042934131280541],
#  'slopeV500-1500_sma3nz_stddevNorm': [0.26420024728110003],
#  'spectralFluxV_sma3nz_amean': [-0.270660972489601],
#  'spectralFluxV_sma3nz_stddevNorm': [-0.46483314676133103],
#  'mfcc1V_sma3nz_amean': [-1.146529140878069],
#  'mfcc1V_sma3nz_stddevNorm': [2.62369969064963],
#  'mfcc2V_sma3nz_amean': [-0.6538215199228321],
#  'mfcc2V_sma3nz_stddevNorm': [-0.9870798432709291],
#  'mfcc3V_sma3nz_amean': [-0.5862493345363421],
#  'mfcc3V_sma3nz_stddevNorm': [-0.136898359767016],
#  'mfcc4V_sma3nz_amean': [-0.32790970406220404],
#  'mfcc4V_sma3nz_stddevNorm': [0.233326761908474],
#  'alphaRatioUV_sma3nz_amean': [0.6572580975330841],
#  'hammarbergIndexUV_sma3nz_amean': [-0.5703889786871841],
#  'slopeUV0-500_sma3nz_amean': [0.099811905332591],
#  'slopeUV500-1500_sma3nz_amean': [-0.6050657739119271],
#  'spectralFluxUV_sma3nz_amean': [-0.103258632136785],
#  'loudnessPeaksPerSec': [1.485090277462697],
#  'VoicedSegmentsPerSec': [1.4186121730921961],
#  'MeanVoicedSegmentLengthSec': [-1.025477173810317],
#  'StddevVoicedSegmentLengthSec': [-0.7903777510627301],
#  'MeanUnvoicedSegmentLength': [-0.635879148110575],
#  'StddevUnvoicedSegmentLength': [-0.8667825347018281],
#  'equivalentSoundLevel_dBp': [-0.37323161766967505]}

# %%
train = train_df
valid = valid_df
test = test_df

# %% [markdown]
# # Majority Baseline
# (Just one dummy feature)

# %%
# this keeps one first feature -- should not be informative enough for the model to work
def features_to_vec(feature_dict):
#     out_vector = []
#     for feature in feature_dict.values():
#         out_vector.append(feature)
    return [0]

# %%
#check that it works and print the dimensions
print(f"The dataset has {len(train['features'])} data samples.")
print(f"Each data sample is a vector of {len(train['features'].apply(features_to_vec)[5])} dimensions.")
# Out:
# The dataset has 7776 data samples.
# Each data sample is a vector of 1 dimensions.

# %%
label_to_idx = {"a":1, "cna":0, "na": 0}
X_train = train['features'].apply(features_to_vec).tolist() 
y_train = [label_to_idx[x] for x in train['intoxicated']]

# X_test = test['features'].apply(features_to_vec).tolist() 
# y_test = [label_to_idx[x] for x in test['intoxicated']]

X_test = valid['features'].apply(features_to_vec).tolist() 
y_test = [label_to_idx[x] for x in valid['intoxicated']]

# %%
def evaluate_classifier(classifier, X_test, y_test):
    y_predicted = classifier.predict(X_test)
    cm = confusion_matrix(y_test, y_predicted)
    sn.heatmap(cm, annot=True, fmt='g')
    plt.xlabel('Predicted')
    plt.ylabel('Expected')

# %%
X_train[2:4]
#look at this; maybe we could collapse redundant features? like do PCA or any other dimensionality reduction
# Out:
# [[0], [0]]

# %%
y_train[:2]
# Out:
# [0, 1]

# %%
X_train = np.array(X_train)
y_train = np.array(y_train)

# %%
nb_classifier = naive_bayes.BernoulliNB()
nb_classifier.fit(X_train, y_train)
accuracy = nb_classifier.score(X_test, y_test)
accuracy
# Out:
# 0.45164609053497945

# %%
evaluate_classifier(nb_classifier, X_test, y_test)

# %% [markdown]
# # Actual Baseline

# %%
# this simply flattens all the features into one long concatenated vector
def features_to_vec(feature_dict):
    out_vector = []
    for feature in feature_dict.values():
        for subfeature in feature:
            out_vector.append(subfeature)
    return out_vector

features_to_vec(train['features'][0])
# Out:
# [1.9716836226420051,
#  -0.144710119756208,
#  1.09525820981226,
#  1.4110744244268552,
#  1.257443689834028,
#  -0.062309013348470006,
#  1.9183377363840561,
#  2.414238571757887,
#  0.234921312543125,
#  0.44480466452833106,
#  -0.131543291107991,
#  -0.075182715121929,
#  -0.724745500054306,
#  0.035368339852342,
#  0.13274961484936001,
#  0.36253534443859503,
#  1.145226168257222,
#  0.826900465550189,
#  0.13682685733003702,
#  0.16099921669721,
#  -0.225905533859719,
#  -0.608610334621792,
#  -2.143077865371419,
#  3.064789464753881,
#  0.28362095379705404,
#  0.101592686331052,
#  -0.8785332023988071,
#  0.46776321517475905,
#  -0.072546235028042,
#  -0.6589946129575951,
#  -0.37185159196093803,
#  -0.610042380180256,
#  1.476049895105589,
#  -0.295763687665587,
#  -0.372236442130687,
#  0.47112731636498506,
#  0.6522588570566861,
#  -0.6971172461035231,
#  -0.081598805976287,
#  -0.20569376925886002,
#  0.9535757340689801,
#  1.077640186944848,
#  -0.968507543591387,
#  0.913639244653036,
#  -0.090339542472001,
#  0.137648015602948,
#  0.394878664908461,
#  0.030714203444137004,
#  -0.255906444303623,
#  0.001834435016838,
#  0.013705637332721001,
#  -0.018149402984678,
#  0.134751975986,
#  0.065574174320423,
#  0.45875858209152504,
#  1.3883923847296091,
#  0.035420642104874,
#  -0.060042464987674,
#  1.094852157832998,
#  -2.211069801185894,
#  -1.161851841529184,
#  2.813482213784022,
#  0.45869376014120805,
#  -0.089014351934321,
#  -0.5042934131280541,
#  0.26420024728110003,
#  -0.270660972489601,
#  -0.46483314676133103,
#  -1.146529140878069,
#  2.62369969064963,
#  -0.6538215199228321,
#  -0.9870798432709291,
#  -0.5862493345363421,
#  -0.136898359767016,
#  -0.32790970406220404,
#  0.233326761908474,
#  0.6572580975330841,
#  -0.5703889786871841,
#  0.099811905332591,
#  -0.6050657739119271,
#  -0.103258632136785,
#  1.485090277462697,
#  1.4186121730921961,
#  -1.025477173810317,
#  -0.7903777510627301,
#  -0.635879148110575,
#  -0.8667825347018281,
#  -0.37323161766967505]

# %%
#check that it works and print the dimensions
print(f"The dataset has {len(train['features'])} data samples.")
print(f"Each data sample is a vector of {len(train['features'].apply(features_to_vec)[7])} dimensions.")
# Out:
# The dataset has 7776 data samples.
# Each data sample is a vector of 88 dimensions.

# %%
label_to_idx = {"a":1, "cna":0, "na": 0}
X_train = train['features'].apply(features_to_vec).tolist() 
y_train = [label_to_idx[x] for x in train['intoxicated']]

X_test = test['features'].apply(features_to_vec).tolist() 
y_test = [label_to_idx[x] for x in test['intoxicated']]

# %%
def evaluate_classifier(classifier, X_test, y_test):
    y_predicted = classifier.predict(X_test)
    cm = confusion_matrix(y_test, y_predicted)
    sn.heatmap(cm, annot=True, fmt='g')
    plt.xlabel('Predicted')
    plt.ylabel('Expected')

# %%
#([set([type(x) for x in y]) for y in X_train])
X_train = np.array(X_train)
y_train = np.array(y_train)

# %%
nb_classifier = naive_bayes.BernoulliNB()
nb_classifier.fit(X_train, y_train)
accuracy = nb_classifier.score(X_test, y_test)
accuracy
# Out:
# 0.6337448559670782

# %%
evaluate_classifier(nb_classifier, X_test, y_test)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import naive_bayes, svm 
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier

# %%
knn_classifier = KNeighborsClassifier()
knn_classifier.fit(X_train, y_train)
accuracy = knn_classifier.score(X_test, y_test)
accuracy
# Out:
# 0.6522633744855967

# %%
evaluate_classifier(knn_classifier, X_test, y_test)

# %%
rf_classifier = RandomForestClassifier()
rf_classifier.fit(X_train, y_train)
accuracy = rf_classifier.score(X_test, y_test)
accuracy
# Out:
# 0.6800411522633745

# %%
evaluate_classifier(rf_classifier, X_test, y_test)

# %%
svm_classifier = svm.LinearSVC()
svm_classifier.fit(X_train, y_train)
accuracy = svm_classifier.score(X_test, y_test)
accuracy
# Out:
# /mount/arbeitsdaten31/studenten1/team-lab-phonetics/2023/student_directories/kolos/NLP4/lib64/python3.10/site-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 0.6718106995884774

# %%
evaluate_classifier(svm_classifier, X_test, y_test)

# %%
svm_classifier = svm.NuSVC(kernel='poly')
svm_classifier.fit(X_train, y_train)
accuracy = svm_classifier.score(X_test, y_test)
accuracy
# Out:
# 0.7016460905349794

# %%
evaluate_classifier(svm_classifier, X_test, y_test)

# %%
logreg_classifier = LogisticRegression()
logreg_classifier.fit(X_train, y_train)
accuracy = logreg_classifier.score(X_test, y_test)
accuracy
# Out:
# /mount/arbeitsdaten31/studenten1/team-lab-phonetics/2023/student_directories/kolos/NLP4/lib64/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.6779835390946503

# %%
evaluate_classifier(logreg_classifier, X_test, y_test)

# %% [markdown]
# # Majority Baseline for the Levels (Regression Task)

# %%
from sklearn import linear_model

# %%
linmodel = linear_model.LinearRegression(fit_intercept=True)

# %%
def features_to_vec(feature_dict, i=0):
    out_vector = [list(feature_dict.values())[i][0]] #first of i-th feature only
    return out_vector

X_train = train['features'].apply(lambda x: features_to_vec(x, i=1)).tolist() 
X_test = test['features'].apply(lambda x: features_to_vec(x, i=1)).tolist() 
y_train = train['breath alcohol concentration']
y_test = test['breath alcohol concentration']
linmodel.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
(slope, intercept) = (linmodel.coef_[0], linmodel.intercept_)
print(slope, intercept)
# Out:
# -1.8521183740941598e-05 0.0004476890432098766

# %%
from sklearn.metrics import mean_squared_error, r2_score
y_pred = linmodel.predict(X_test)
print("Mean squared error: %.2f" % mean_squared_error(y_test, y_pred))
# The coefficient of determination: 1 is perfect prediction
print("Coefficient of determination: %.2f" % r2_score(y_test, y_pred))
# Out:
# Mean squared error: 0.00
# Coefficient of determination: 0.00

# %%
import matplotlib.pyplot as plt
# Plot outputs
#based on the one dimension of features
x_test_0 = [x[0] for x in X_test]

plt.scatter(x_test_0, y_test, color="black")
plt.scatter(x_test_0, y_pred, color="blue")
#plt.plot(x_test_0, y_pred, color="blue", linewidth=3)

plt.xticks(())
plt.yticks(())

plt.show()

# %%
#Find the feature that produces the best results (the best r2_score)
r2_score_max = -1
i_max = 0
for i in range(len(train['features'][0].keys())):
    linmodel = linear_model.LinearRegression(fit_intercept=True)
    X_train = train['features'].apply(lambda x: features_to_vec(x, i=i)).tolist() 
    X_test = test['features'].apply(lambda x: features_to_vec(x, i=i)).tolist() 
    y_train = train['breath alcohol concentration']
    y_test = test['breath alcohol concentration']
    linmodel.fit(X_train, y_train)
    y_pred = linmodel.predict(X_test)
    r2_score_cur = r2_score(y_test, y_pred)
    if r2_score_cur > r2_score_max:
        i_max = i
        r2_score_max = r2_score_cur

# %%
print(i_max, r2_score_max)

linmodel = linear_model.LinearRegression(fit_intercept=True)
X_train = train['features'].apply(lambda x: features_to_vec(x, i=i_max)).tolist() 
X_test = test['features'].apply(lambda x: features_to_vec(x, i=i_max)).tolist() 
y_train = train['breath alcohol concentration']
y_test = test['breath alcohol concentration']
linmodel.fit(X_train, y_train)
y_pred = linmodel.predict(X_test)
print("Mean squared error: %.2f" % mean_squared_error(y_test, y_pred))
# The coefficient of determination: 1 is perfect prediction
print("Coefficient of determination: %.2f" % r2_score(y_test, y_pred))
plt.scatter(X_test, y_test, color="black")
plt.scatter(X_test, y_pred, color="blue")
plt.xticks(())
plt.yticks(())

plt.show()
# Out:
# 62 0.04128598000823991
# Mean squared error: 0.00
# Coefficient of determination: 0.04

# %% [markdown]
# ## On only those who have non-0 alc level
# ### In the breath
# Feature 38 seems to be correlated with the alcohol level in blood

# %%
#Find the feature that produces the best results (the best r2_score)
r2_score_max = -1
i_max = 0
for i in range(len(train['features'][0].keys())):
    linmodel = linear_model.LinearRegression(fit_intercept=True)
    X_train = train['features'].apply(lambda x: features_to_vec(x, i=i)).tolist() 
    X_test = test['features'].apply(lambda x: features_to_vec(x, i=i)).tolist() 
    y_train = train['breath alcohol concentration']
    y_test = test['breath alcohol concentration']
    linmodel.fit(X_train, y_train)
    y_pred = linmodel.predict(X_test)
    r2_score_cur = r2_score(y_test, y_pred)
    if r2_score_cur > r2_score_max:
        i_max = i
        r2_score_max = r2_score_cur
        
print(i_max, r2_score_max)

linmodel = linear_model.LinearRegression(fit_intercept=True)
X_train = train['features'].apply(lambda x: features_to_vec(x, i=i_max)).tolist() 
X_test = test['features'].apply(lambda x: features_to_vec(x, i=i_max)).tolist() 
y_train = train['breath alcohol concentration']
y_test = test['breath alcohol concentration']
linmodel.fit(X_train, y_train)
y_pred = linmodel.predict(X_test)
print("Mean squared error: %.2f" % mean_squared_error(y_test, y_pred))
# The coefficient of determination: 1 is perfect prediction
print("Coefficient of determination: %.2f" % r2_score(y_test, y_pred))
plt.scatter(X_test, y_test, color="black")
plt.scatter(X_test, y_pred, color="blue")
plt.xticks(())
plt.yticks(())

plt.show()
# Out:
# 62 0.04128598000823991
# Mean squared error: 0.00
# Coefficient of determination: 0.04

# %%
# !pwd
# Out:
# /mount/arbeitsdaten31/studenten1/team-lab-phonetics/2023/student_directories/kolos/CLTeamLab/intoxicat/baselines
